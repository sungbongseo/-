rows x 26 columns]

# %%
df.columns
# Out:
# Index(['NAME', 'SEX', 'S', 'a1', 'a2', 'a3', 'a4', 'b1', 'b2', 'b3', 'b4',
#        'c1', 'c2', 'c3', 'c4', 'd1', 'd2', 'd3', 'd4', 'e1', 'e2', 'e3', 'e4',
#        'e5', 'f1', 'f2', 'f3', 'f4'],
#       dtype='object')

# %%
items = df.columns.tolist()[2:]
items.sort()

# %%
from factor_analyzer import FactorAnalyzer

# %%
fa = FactorAnalyzer(n_factors=7, method="ml", rotation="promax")

# %%
fa.fit(df[items])
# Out:
# FactorAnalyzer(bounds=(0.005, 1), impute='median', is_corr_matrix=False,
#                method='ml', n_factors=7, rotation='promax', rotation_kwargs={},
#                use_smc=True)

# %%
fa.loadings_
# Out:
# array([[ 1.08158802e-01, -7.21988155e-02, -6.65609209e-02,
#         -3.98191153e-02, -7.48711884e-02,  2.40226106e-02,
#         -1.99081357e-01],
#        [ 4.52346174e-01, -1.98951369e-01,  4.68165356e-01,
#          3.08929863e-01, -1.26862966e-01,  4.01369830e-02,
#          4.41778910e-02],
#        [ 6.71480112e-03, -3.81962963e-01, -5.34767341e-02,
#          1.12262258e+00, -7.67334915e-03,  9.57753204e-02,
#          1.14077686e-01],
#        [ 5.95307493e-01,  2.51610603e-01,  1.32409701e-01,
#          4.86127047e-03, -9.45714515e-02, -2.57479053e-02,
#         -5.74661988e-04],
#        [ 5.39819719e-01,  1.50910064e-01,  2.16289416e-01,
#          1.84209237e-01, -1.97591718e-02,  3.53468691e-02,
#         -1.13113280e-01],
#        [ 1.01284724e-01, -7.01975188e-04, -9.05965397e-02,
#          1.45321540e-02,  9.54665137e-04,  1.29912456e-01,
#          5.40740606e-01],
#        [-3.82338372e-02, -2.94707743e-01,  6.95996023e-01,
#         -4.37169271e-02, -1.82183932e-01,  9.71267652e-02,
#         -1.52262588e-02],
#        [ 3.27461281e-01,  4.90415814e-01,  5.70708914e-01,
#         -2.58063066e-01, -5.50656760e-02,  1.86662879e-02,
#         -9.96249079e-02],
#        [-1.17593679e-01,  1.10182797e-01,  8.75076448e-01,
#          7.55552445e-02,  1.99047928e-01,  6.24928089e-02,
#         -1.44063082e-01],
#        [ 1.96398440e-01, -7.91487486e-02, -3.81338805e-02,
#          2.17613579e-02,  2.84880463e-01, -1.56646913e-01,
#          1.30673752e-01],
#        [ 1.55976534e-01, -7.09997566e-02,  3.76232718e-02,
#         -2.70083412e-02,  5.27133469e-01, -4.26983848e-02,
#          3.32953233e-01],
#        [-5.35296568e-02, -4.21871130e-02,  1.01731591e-01,
#         -1.05593573e-01,  6.21598104e-01,  1.32976277e-01,
#         -8.31452994e-02],
#        [-1.92459811e-01,  5.43538359e-02,  1.28042539e-02,
#          7.73006643e-02,  6.56256698e-01,  2.61549061e-02,
#         -1.50345816e-02],
#        [-5.43255048e-02,  3.91490200e-01,  4.48955870e-01,
#          1.01209497e-01,  4.21017714e-03, -3.51504717e-02,
#         -9.70572120e-02],
#        [ 1.13998391e-01,  5.23846495e-01,  2.12295762e-01,
#         -2.28907544e-02,  9.36208052e-02,  2.07476671e-01,
#          2.31123714e-01],
#        [ 1.27962198e-01,  9.21243029e-01, -1.76215281e-01,
#         -1.29719804e-01, -1.24258930e-03, -1.37345009e-01,
#         -6.51258802e-02],
#        [ 7.88460670e-02,  7.10849968e-01, -1.40980615e-01,
#         -1.83122681e-01, -7.17487424e-02,  3.74861563e-02,
#          8.64353657e-02],
#        [ 1.12035895e-01, -7.75553529e-02,  2.10983702e-02,
#         -9.85243790e-02,  1.58494060e-01, -3.09766505e-01,
#         -1.83053660e-01],
#        [ 7.71315850e-02,  8.78008087e-03, -7.35189602e-03,
#          2.25230346e-01, -4.31431225e-02, -2.18281909e-01,
#         -4.90288826e-02],
#        [ 1.86880143e-02,  8.07290155e-02, -4.45929443e-01,
#          3.80547387e-02, -8.05903989e-02,  5.83725847e-02,
#         -4.15725917e-02],
#        [ 6.54323599e-01,  1.65446128e-01, -1.83308258e-01,
#          1.11588607e-01, -7.35385107e-02,  4.55093592e-02,
#          1.09298473e-01],
#        [ 8.39100866e-02,  3.14121081e-01,  3.91279879e-02,
#          2.87787299e-01,  9.24520276e-02,  1.08116008e-01,
#          1.22547339e-01],
#        [ 2.37786944e-01, -3.12712738e-02,  1.12161312e-01,
#         -2.14394800e-02,  1.46587285e-01,  6.67084562e-01,
#          3.65970088e-02],
#        [ 5.45874576e-01, -2.46347837e-01,  1.27973742e-01,
#         -1.29213318e-01, -7.42264292e-02,  5.12333783e-01,
#          1.08462371e-01],
#        [ 8.67127632e-01,  6.46030966e-02, -1.50048511e-01,
#         -1.10469596e-01,  5.36412534e-02,  5.77118333e-02,
#         -3.52056620e-02],
#        [ 2.91563141e-01,  1.43748656e-02, -3.52747883e-01,
#          2.51714853e-01,  3.07154295e-01,  6.25621034e-01,
#         -3.54770977e-01]])

# %%
efa_result= pd.DataFrame(fa.loadings_, index=items)

# %%
plt.figure(figsize=(15,20))
sns.heatmap(efa_result, cmap="Reds", annot=True, fmt='.2f')

# %%
def CronbachAlpha(itemscores):
    itemscores = np.asarray(itemscores)
    itemvars = itemscores.var(axis=0, ddof=1)
    tscores = itemscores.sum(axis=1)
    nitems = itemscores.shape[1]
    
    return (nitems / (nitems-1)) * (1 - (itemvars.sum() / tscores.var(ddof=1)))

# %%
factors = ['s', 'a1', 'a2', 'a3', 'a4', 'b1', 'b2', 'b3', 'b4', 'c1', 'c2', 'c3', 'c4', 'd1', 'd2', 'd3', 'd4', 'e1', 'e2', 'e3', 'e4', 'e5', 'f1', 'f2', 'f3', 'f4']
factors_items_dict = {}

for factor in factors:
    factors_items_dict[factor] = [x for x in items if x[0] == factor]

# %%
for key, value in factors_items_dict.items():
    print(key)
    print(CronbachAlpha(df[value]))
    print()
# Out:
# s
# nan
#
# a1
# nan
#
# a2
# nan
#
# a3
# nan
#
# a4
# nan
#
# b1
# nan
#
# b2
# nan
#
# b3
# nan
#
# b4
# nan
#
# c1
# nan
#
# c2
# nan
#
# c3
# nan
#
# c4
# nan
#
# d1
# nan
#
# d2
# nan
#
# d3
# nan
#
# d4
# nan
#
# e1
# nan
#
# e2
# nan
#
# e3
# nan
#
# e4
# nan
#
# e5
# nan
#
# f1
# nan
#
# f2
# nan
#
# f3
# nan
#
# f4
# nan
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys
